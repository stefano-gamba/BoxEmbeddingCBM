# %%
import sys, os
# ensure parent directory is on the path so `src` package can be imported
sys.path.insert(0, os.path.abspath('..'))

# %%
# configura per importare da src
import sys
sys.path.append('./src')

# %% [markdown]
# ## Box creation

# %% [markdown]
# ### Load dataset

# %%
import re

concepts_file = '../AwA2_Dataset_Labels/Animals_with_Attributes2/extended_concepts.txt'
def parse_concepts(filepath):
    """Legge il file dei concetti e restituisce una lista ordinata."""
    concepts = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            # Rimuove eventuali tag come 
            line = re.sub(r'\\', '', line).strip()
            if not line:
                continue
            parts = line.split()
            # Assumiamo che il primo elemento sia l'ID e il resto il nome del concetto
            if len(parts) >= 2:
                concepts.append(parts[1])
    return concepts
concepts = parse_concepts(concepts_file)

# %%
import re

classes_file = '../AwA2_Dataset_Labels/Animals_with_Attributes2/classes.txt'
def parse_classes(filepath):
    """Legge il file delle classi e restituisce una lista ordinata."""
    classes = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            # Rimuove eventuali tag come 
            line = re.sub(r'\\', '', line).strip()
            if not line:
                continue
            parts = line.split()
            # Assumiamo che il primo elemento sia l'ID e il resto il nome della classe
            if len(parts) >= 2:
                classes.append(parts[1])
    return classes

classes = parse_classes(classes_file)

# %%
import json

JSON_PATH='../AwA2_Dataset_Labels/Animals_with_Attributes2/supervisioni_gerarchia.json'
def load_data(json_path, concepts):
    with open(json_path, 'r') as f:
        data = json.load(f)
        
    concept2id = {c: idx for idx, c in enumerate(concepts)}
    id2concept = {idx: c for c, idx in concept2id.items()}
    
    # Prepariamo il dataset nel formato [(id_i, id_j, label), ...]
    dataset = []
    for item in data:
        dataset.append((concept2id[item[0]], concept2id[item[1]], float(item[2])))
        
    return dataset, concept2id, id2concept

# %%
dataset, concept2id, id2concept = load_data(JSON_PATH, concepts)

# %% [markdown]
# ### Train

# %%
from src.CHM.model import BoxHierarchyModel
from src.CHM.train import train_box
import torch.nn as nn
from torch.optim import Adam

LR = 0.05

box_model = BoxHierarchyModel(num_concepts=len(concept2id), dim=32)
optimizer = Adam(box_model.parameters(), lr=LR)
criterion = nn.BCELoss() # Binary Cross Entropy
# Out:
# AllenNLP not available. Registrable won't work.

# %%
train_box(box_model, optimizer, criterion, dataset, concept2id, id2concept)
# Out:
# Trovati 50 concetti unici e 583 relazioni supervisionate.
#
# Inizio Addestramento...
# Epoca [1/100] | Loss: 1.4628
# Epoca [10/100] | Loss: 0.1925
# Epoca [20/100] | Loss: 0.0551
# Epoca [30/100] | Loss: 0.0210
# Epoca [40/100] | Loss: 0.0106
# Epoca [50/100] | Loss: 0.0065
# Epoca [60/100] | Loss: 0.0048
# Epoca [70/100] | Loss: 0.0039
# Epoca [80/100] | Loss: 0.0034
# Epoca [90/100] | Loss: 0.0031
# Epoca [100/100] | Loss: 0.0029
#
# Addestramento completato!
#
# Verifica di alcune predizioni post-addestramento:
# Relazione: Animal | arm
#  - P_teorica: 1.0 -> P_predetta: 1.0000
# Relazione: lower_body_part | big
#  - P_teorica: 0.0 -> P_predetta: 0.0052
# Relazione: yellow | wings
#  - P_teorica: 0.0 -> P_predetta: 0.0000

# %% [markdown]
# ### Visualization

# %%
from src.CHM.visualization import visualize_concept_hierarchy, visualize_heatmap_compare, visualize_all_boxes_2d

# %%
visualize_heatmap_compare(box_model, dataset, concept2id, id2concept)

# %%
# cambiare dim_x e dim_y (da 0 a 31) per esplorare la "forma" da diverse angolazioni
visualize_all_boxes_2d(box_model, id2concept, dim_x=0, dim_y=1)

# %%
visualize_concept_hierarchy(box_model, id2concept, concept2id, "brown", "orange")
visualize_concept_hierarchy(box_model, id2concept, concept2id, "brown", "yellow")
visualize_concept_hierarchy(box_model, id2concept, concept2id, "orange", "yellow")
visualize_concept_hierarchy(box_model, id2concept, concept2id, "big", "small")

# %% [markdown]
# ### Save boxes

# %%
from src.utils.box import get_box_dict

box_dict = get_box_dict(box_model, id2concept)

# %% [markdown]
# ## CBM

# %% [markdown]
# ### Load dataset

# %%
import torch
torch.save(box_model.state_dict(), "modello_gerarchia.pth")

# %%
box_model.load_state_dict(torch.load("modello_gerarchia.pth"))
# Out:
# <All keys matched successfully>

# %%
box_dict = get_box_dict(box_model, id2concept)

# %%
from src.utils.dataset import classical_split_awa2_features
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from src.utils.box import prepara_tensore_box

features_path = '../AwA2_Dataset_Features/Animals_with_Attributes2/Features/ResNet101/AwA2-features.txt'
labels_path = '../AwA2_Dataset_Features/Animals_with_Attributes2/Features/ResNet101/AwA2-labels.txt'

(X_train, y_train), (X_val, y_val), (X_test, y_test) = classical_split_awa2_features(
    features_path, labels_path, test_size=0.2, val_size=0.1, random_seed=42
)
class_concept_matrix = torch.from_numpy(np.loadtxt('../Awa2_Dataset_Labels/Animals_with_Attributes2/extended_matrix.txt', dtype=int))

box_tensors = prepara_tensore_box(box_dict, concept2id)

BOX_DIM = 32
BATCH_SIZE = 32
EPOCHS = 20
NUM_CLASSES = len(set(y_train))
NUM_CONCEPTS = len(concept2id)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

train_dataset = TensorDataset(torch.tensor(X_train).float(), torch.tensor(y_train).long())
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_dataset = TensorDataset(torch.tensor(X_val).float(), torch.tensor(y_val).long())
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, pin_memory=True)
test_dataset = TensorDataset(torch.tensor(X_test).float(), torch.tensor(y_test).long())
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, pin_memory=True)
# Out:
# Caricamento dei dati in corso... (potrebbe richiedere qualche secondo)
# Dataset caricato correttamente: 37322 campioni con 2048 feature ciascuno.
#
# --- Risultati dello Split Stratificato (50 Classi) ---
# Training set:   26124 campioni
# Validation set: 3733 campioni
# Test set:       7465 campioni
# Using device: cpu

# %%
from src.CHM.model import ConceptBottleneckClassifier
from src.CHM.train import train_cbm_classifier
import matplotlib.pyplot as plt
from src.CHM.test import test_cbm_classifier
from src.utils.plot import plot_test_results

# %% [markdown]
# ### ORACLE

# %% [markdown]
# #### Train

# %%
info = "rel_matrix"
b_model = ConceptBottleneckClassifier(
    box_dim=box_tensors.size(-1), 
    num_classes=NUM_CLASSES, 
    num_concepts=NUM_CONCEPTS,
    info=info
)
optimizer = torch.optim.Adam(b_model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

b_history = train_cbm_classifier(
    b_model, 
    train_dataloader, 
    val_dataloader, 
    optimizer, 
    criterion, 
    class_concept_matrix, 
    box_tensors, 
    EPOCHS, 
    device,
    info=info
)
# Out:
# Inizio addestramento del classificatore (c -> y)...
# Epoca   2/20 | TRAIN: Loss=2.869, Acc=24.2% | VAL: Loss=2.449, Acc=27.1%
# Epoca   3/20 | TRAIN: Loss=2.225, Acc=44.7% | VAL: Loss=2.054, Acc=47.1%
# Epoca   4/20 | TRAIN: Loss=1.918, Acc=57.7% | VAL: Loss=1.806, Acc=61.7%
# Epoca   5/20 | TRAIN: Loss=1.692, Acc=66.4% | VAL: Loss=1.596, Acc=67.7%
# Epoca   6/20 | TRAIN: Loss=1.506, Acc=70.7% | VAL: Loss=1.423, Acc=76.3%
# Epoca   7/20 | TRAIN: Loss=1.351, Acc=74.6% | VAL: Loss=1.284, Acc=72.2%
# Epoca   8/20 | TRAIN: Loss=1.214, Acc=77.6% | VAL: Loss=1.159, Acc=79.3%
# Epoca   9/20 | TRAIN: Loss=1.098, Acc=80.0% | VAL: Loss=1.029, Acc=83.4%
# Epoca  10/20 | TRAIN: Loss=0.995, Acc=83.0% | VAL: Loss=0.948, Acc=80.0%
# Epoca  11/20 | TRAIN: Loss=0.906, Acc=85.1% | VAL: Loss=0.859, Acc=87.5%
# Epoca  12/20 | TRAIN: Loss=0.829, Acc=86.9% | VAL: Loss=0.795, Acc=81.4%
# Epoca  13/20 | TRAIN: Loss=0.761, Acc=87.5% | VAL: Loss=0.726, Acc=87.3%
# Epoca  14/20 | TRAIN: Loss=0.700, Acc=89.3% | VAL: Loss=0.674, Acc=92.4%
# Epoca  15/20 | TRAIN: Loss=0.646, Acc=90.5% | VAL: Loss=0.615, Acc=93.3%
# Epoca  16/20 | TRAIN: Loss=0.601, Acc=90.9% | VAL: Loss=0.578, Acc=92.8%
# Epoca  17/20 | TRAIN: Loss=0.558, Acc=91.4% | VAL: Loss=0.541, Acc=92.3%
# Epoca  18/20 | TRAIN: Loss=0.521, Acc=92.1% | VAL: Loss=0.502, Acc=89.7%
# Epoca  19/20 | TRAIN: Loss=0.487, Acc=92.4% | VAL: Loss=0.467, Acc=93.8%
# Epoca  20/20 | TRAIN: Loss=0.458, Acc=92.7% | VAL: Loss=0.437, Acc=93.9%
# Epoca  21/20 | TRAIN: Loss=0.430, Acc=93.0% | VAL: Loss=0.415, Acc=92.3%
# Addestramento completato.

# %% [markdown]
# #### Test

# %%
accuracy, preds, labels = test_cbm_classifier(
     model=b_model,
     test_dataloader=test_dataloader,
     class_concept_matrix=class_concept_matrix,
     boxes_tensor=box_tensors,
     oracle=True,
     device="cuda" if torch.cuda.is_available() else "cpu",
     info=info
)
# Out:
# Inizio valutazione sul Test Set...
#
# Accuratezza Totale: 85.45%

# %% [markdown]
# ### ABLATION SABOTAGE

# %%
# 1. Definiamo i "Nodi Padre" (Macro Concept) da SALVARE
macro_concepts_to_keep = [
    'Animal', 
    'upper_body_part', 
    'lower_body_part', 
    'head', 
    'leg', 
    'foot', 
    'mouth', 
    'tooth', 
    'skin_pattern'
]

# 2. Generiamo il sabotaggio per TUTTE le classi
extreme_modifications = []
for cls_name in classes:
    for concept in concepts: # Assicurati di avere a scope la lista completa dei nomi dei concetti
        # Se il concetto NON è nella lista dei macro-concetti, lo radiamo al suolo (0.0)
        if concept not in macro_concepts_to_keep:
            extreme_modifications.append((cls_name, concept, 0.0))

# 3. (Opzionale) Iniezioni Letali (Falsi Positivi)
# Visto che stiamo già azzerando tutte le foglie, l'accuracy crollerà comunque.
# Tuttavia, aggiungere un'allucinazione (es. dare le pinne alla tigre) DOPO
# averle tolto tutti i suoi tratti distintivi, manderà i logit completamente in negativo.
iniezioni_letali = [
    ('killer+whale', 'hooves', 1.0), # Un'orca con gli zoccoli
    ('tiger', 'flippers', 1.0),      # Una tigre con le pinne
    ('horse', 'flys', 1.0),          # Un cavallo che vola
    ('bat', 'tusks', 1.0),           # Un pipistrello con le zanne da elefante
    ('moose', 'spots', 1.0)          # Un alce a pois
]

extreme_modifications.extend(iniezioni_letali)

# %%
# Un sabotaggio chirurgico su 5 classi per testare l'Antivirus Logico
virus_modifications = [
    # 1. TIGRE: La trasformiamo in un erbivoro
    ('tiger', 'hooves', 1.0),      # Iniezione zoccoli
    ('tiger', 'horns', 1.0),       # Iniezione corna
    ('tiger', 'chewteeth', 1.0),   # Iniezione denti piatti
    ('tiger', 'stripes', 0.0),     # Spegniamo il suo tratto forte
    
    # 2. CAVALLO: Lo trasformiamo in un predatore
    ('horse', 'meatteeth', 1.0),
    ('horse', 'claws', 1.0),
    ('horse', 'hooves', 0.0),
    
    # 3. DELFINO: Lo facciamo diventare terrestre
    ('dolphin', 'longleg', 1.0),
    ('dolphin', 'furry', 1.0),
    ('dolphin', 'walks', 1.0),
    ('dolphin', 'flippers', 0.0),
    
    # 4. PIPISTRELLO: Lo facciamo diventare un animale marino
    ('bat', 'swims', 1.0),
    ('bat', 'flippers', 1.0),
    ('bat', 'wings', 0.0),
    ('bat', 'flys', 0.0),
    
    # 5. ORSO GRIZZLY: Lo facciamo diventare una scimmia
    ('grizzly+bear', 'hands', 1.0),
    ('grizzly+bear', 'tail', 1.0), # (Gli orsi non hanno coda lunga in questo dataset)
    ('grizzly+bear', 'big', 0.0)
]

# %%
from src.utils.ablation import sabotage_concept_matrix

sabotaged_matrix = sabotage_concept_matrix(
    class_concept_matrix,
    classes,
    concepts,
    extreme_modifications,
)
# Out:
# Sabotaggio: antelope -> black | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio
Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: killer+whale -> walks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: killer+whale -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: killer+whale -> quadrapedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: killer+whale -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: killer+whale -> swims | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: killer+whale -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> black | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> white | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> brown | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> gray | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> toughskin | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> big | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> small | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> bulbous | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> lean | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> pads | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> longleg | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> meatteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> buckteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> strainteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> claws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> walks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: beaver -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> white | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> brown | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> gray | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> patches | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> spots | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> hairless | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> bulbous | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> lean | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> pads | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> longleg | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> meatteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> claws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dalmatian -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> black | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> white | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> blue | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> brown | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> gray | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> big | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> small | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> bulbous | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> lean | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> pads | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> longleg | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> meatteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> claws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: persian+cat -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> white | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> brown | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> gray | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> patches | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> toughskin | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> bulbous | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> lean | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> hooves | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> pads | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> paws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> longleg | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> longneck | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> meatteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> buckteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> claws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: horse -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> white | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> brown | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> gray | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> patches | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> bulbous | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> lean | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> pads | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> longleg | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> meatteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> claws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: german+shepherd -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> black | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> white | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> blue | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> brown | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> gray | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> spots | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> furry | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> hairless | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> toughskin | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> bulbous | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> lean | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> flippers | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> pads | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> paws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> longleg | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> chewteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> meatteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> strainteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> claws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> walks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> quadrapedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> swims | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: blue+whale -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> white | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> brown | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> gray | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> patches | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> big | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> small | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> bulbous | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> lean | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> pads | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> longleg | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> meatteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> claws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: siamese+cat -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> white | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> brown | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> gray | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> stripes | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> big | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> small | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> bulbous | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> lean | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> pads | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> longleg | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> chewteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> meatteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> claws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: skunk -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> white | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> brown | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> gray | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> big | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> small | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> bulbous | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> lean | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> pads | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> longleg | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> tail | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> meatteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> buckteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> claws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: mole -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: mole -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> white | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> brown | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> gray | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> orange | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> stripes | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> bulbous | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> lean | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> pads | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> longleg | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> meatteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> buckteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> claws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: tiger -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> black | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> white | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> brown | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> gray | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> furry | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> hairless | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> toughskin | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> bulbous | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> lean | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> pads | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> paws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> longleg | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> tail | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> meatteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> strainteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> claws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: hippopotamus -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> black | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> white | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> brown | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> gray | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> yellow | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> patches | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> spots | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> toughskin | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> bulbous | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> lean | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> hooves | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> pads | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> paws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> longleg | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> longneck | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> chewteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> meatteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> horns | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> claws | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> walks | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> quadrapedal | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> swims | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: leopard -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> black | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> white | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> blue | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> brown | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> gray | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> orange | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> red | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> yellow | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> patches | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> spots | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> stripes | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> furry | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> hairless | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> toughskin | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> small | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> bulbous | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> lean | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> flippers | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> hands | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> hooves | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> pads | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> paws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> longleg | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> longneck | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> tail | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> chewteeth | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> meatteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> buckteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> strainteeth | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: moose -> horns | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: moose -> claws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio
Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> claws | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> tusks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> flys | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> hops | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> walks | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> bipedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> quadrapedal | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> arm | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> swims | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> wings | Vecchio: 0.0 -> Nuovo: 0.0
# Sabotaggio: killer+whale -> hooves | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: tiger -> flippers | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: horse -> flys | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: bat -> tusks | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: moose -> spots | Vecchio: 0.0 -> Nuovo: 1.0
# Completato: 2055 modifiche applicate.

# %%
from src.utils.ablation import sabotage_concept_matrix
sabotaged_matrix = sabotage_concept_matrix(
    class_concept_matrix, 
    classes, 
    concepts, 
    virus_modifications
)
# Out:
# Sabotaggio: tiger -> hooves | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: tiger -> horns | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: tiger -> chewteeth | Vecchio: 1.0 -> Nuovo: 1.0
# Sabotaggio: tiger -> stripes | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: horse -> meatteeth | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: horse -> claws | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: horse -> hooves | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: dolphin -> longleg | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: dolphin -> furry | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: dolphin -> walks | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: dolphin -> flippers | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: bat -> swims | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: bat -> flippers | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: bat -> wings | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: bat -> flys | Vecchio: 1.0 -> Nuovo: 0.0
# Sabotaggio: grizzly+bear -> hands | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: grizzly+bear -> tail | Vecchio: 0.0 -> Nuovo: 1.0
# Sabotaggio: grizzly+bear -> big | Vecchio: 1.0 -> Nuovo: 0.0
# Completato: 18 modifiche applicate.

# %%
accuracy, preds, labels = test_cbm_classifier(
     model=b_model,
     test_dataloader=test_dataloader,
     class_concept_matrix=sabotaged_matrix,
     boxes_tensor=box_tensors,
     oracle=True,
     device="cuda" if torch.cuda.is_available() else "cpu",
     info=info
)
# Out:
# Inizio valutazione sul Test Set...
#
# Accuratezza Totale: 86.97%

# %% [markdown]
# ### RELATION MATRIX FEEDBACK

# %%
accuracy, preds, labels = test_cbm_classifier(
     model=b_model,
     test_dataloader=test_dataloader,
     class_concept_matrix=sabotaged_matrix,
     boxes_tensor=box_tensors,
     oracle=True,
     device="cuda" if torch.cuda.is_available() else "cpu",
     smoothing_logic=True,
     alpha=0.1,
     info=info
)
# Out:
# Inizio valutazione sul Test Set...
#
# Accuratezza Totale: 0.78%
